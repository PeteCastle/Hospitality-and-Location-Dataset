# %%
from tripadvisor_restaurant import TripadvisorRestaurant
from tripadvisor_hotel import TripadvisorHotel
from tripadvisor_touristsite import TripadvisorTouristSite

# %%
# resto = TripadvisorRestaurant(NUM_PAGES=5)
# resto.extractData(["Manila"])
# d1, d2 = resto.getDataframe()

hotel = TripadvisorTouristSite(NUM_PAGES=1)
hotel.extractData(["Manila"])
d1, d2 = hotel.getDataframe()

display(d1)
display(d2)
# Out:
# 2023-08-21 16:19:53 INFO Scraped the URLS of 30 selected tourist destinations in Manila
# 2023-08-21 16:19:56 INFO Scraped all details from Intramuros
# 2023-08-21 16:19:58 INFO Scraped all details from Fort Santiago
# 2023-08-21 16:20:00 INFO Scraped all details from San Agustin Church
# 2023-08-21 16:20:02 INFO Scraped all details from Rizal Park
# 2023-08-21 16:20:04 INFO Scraped all details from Manila Cathedral
# 2023-08-21 16:20:06 INFO Scraped all details from National Museum
# 2023-08-21 16:20:08 INFO Scraped all details from Museo San Agustin
# 2023-08-21 16:20:09 INFO Scraped all details from Robinsons Place Mall
# 2023-08-21 16:20:12 INFO Scraped all details from Manila Ocean Park
# 2023-08-21 16:20:13 INFO Scraped all details from Manila Bay
# 2023-08-21 16:20:15 INFO Scraped all details from Divisoria Market
# 2023-08-21 16:20:17 INFO Scraped all details from University of Santo Tomas
# 2023-08-21 16:20:19 INFO Scraped all details from Casa Manila
# ...
