# %% [markdown]
# # SP702 Final Project (Task 3)
#
# **By**: Francis Mark M. Cayco
#
# **Github profile**: https://github.com/PeteCastle
#
# **Instructions:**
# **Task 3: Prepare tourist site data**
# Extract **tourist site** data (Note: at least 25 different tourist sites)
# - Tourist Site Name
# - Classification (e.g. museum, park, zoo, etc.)
# - Location (Note: Barangay, City/Municipality, Province)
# - Number of visitors per year (Note: in thousands)
# - Entrance fee (Note: Peso)
# - Other data (extract more data regarding tourist sites that can be used by tourists)
# - Customer reviews of tourist site from review sites. Make sure that each review is unique and posted by different users (i.e. no duplicate reviews and no duplicate username).
#
# Store the collected data to a csv file. File name format: **Tourist_site.csv **
#
# Please upload your Jupyter notebook file. Filename format: **Extract_Tourist_site_Source.ipynb**. Note that you might need to create different python code per source of data. Submit all code you used to extract data.
# SPARTA
#
# ## Data Sources
# 1. TripAdvisor (https://www.tripadvisor.com.ph)
# 2. RapidAPI's TripAdvisor Endpoint (https://rapidapi.com/apidojo/api/travel-advisor)
#
# ## How did I extract the data?
# 1. The GeoID of the location is obatined using the **RapidAPI's TripAdvisor Endpoint**. The GeoID is used to get the data from the TripAdvisor website.
# 2. The GeoID is referenced in the TripAdvisor website, returning the URLs of hotel, restaurants, and attractions in the location.
# 3. The list of toursit site and detail of each toursit site is obtained from the TripAdvisor website.
# 4. **BeautifulSoup** library to is used to extract the data tourist site page.
#
# The extracted data is stored in a **CSV** file.  One for the list of toursit site and another for the user reviews of each toursit site.
#
#
# ## Website Screenshots
# ![](resources/images/2023-08-26-16-07-39.png)
# ![](resources/images/2023-08-26-16-08-00.png)
#
#
# ## What are the list of the data that I have extracted?
#
# | **Tourist Site Information** |                    |
# |--------------------------|--------------------|
# | Name                     | Name of the tourist site |
# | Location                 | Location of the tourist site |
# | URL                      | URL of the tourist site |
# | About                    | About the tourist site |
# | Operating_Hours          | Operating hours of the tourist site |
# | Trip_Duration            | Suggested trip duration of the tourist site |
# | Site_Type                | Type of the tourist site |
# | Rating                   | Rating of the tourist site |
# | Review_Count             | Number of reviews of the tourist site |
# | Rating_Description       | Rating description of the tourist site |
# | Entrance_Fee             | Entrance fee of the tourist site |
# | Address                  | Address of the tourist site |
# | **Tourist Site Review Information** |                           |
# |------------------------------------|---------------------------|
# | Name                               | Name of the tourist site  |
# | URL                                | URL of the tourist site   |
# | Title                              | Title of the review       |
# | User_Link                          | Link to the user's profile |
# | User_Name                          | Name of the user          |
# | Rating                             | Rating of the review      |
# | Content                            | Content of the review     |
# | Visit_Date                         | Date of visit             |
# | Purpose                            | Purpose of the visit      |
# | Review_Date                        | Date of the review        |

# %%
# The full code is in the file `tripadvisor/tourist_site.py`
from tripadvisor.tourist_site import TripadvisorTouristSite

NUM_PAGES = 1 # Number of pages to scrape.  The total number of tourist site scraped is NUM_PAGES * 30

# List of locations to scrape.  
#  Note that if the location is present in datasets/locations.json, the location will be scraped. 
#  Otherwise, the location will have to be obtained from RapidAPI's Tripadvisor API, which require credential access.
#  The locations available are: Manila, Baguio, Cavite, and Tagaytay
locations = ["Manila", "Cavite","Tagaytay"] 

tourist_site = TripadvisorTouristSite(NUM_PAGES)
tourist_site.extractData(locations)
tourist_site_details, tourist_site_reviews = tourist_site.getDataframe()

print("Tourist Site Details")
display(tourist_site_details.head(5))

print("Tourist Site Reviews")
display(tourist_site_reviews.head(5))
# Out:
# 2023-08-26 16:12:17 INFO Scraping the URLS of selected restaurants in Manila
# 2023-08-26 16:12:22 INFO Scraped the URLS of 30 selected tourist destinations in Manila
# 2023-08-26 16:12:24 INFO Scraped all details from Intramuros
# 2023-08-26 16:12:25 INFO Scraped all details from Fort Santiago
# 2023-08-26 16:12:27 INFO Scraped all details from San Agustin Church
# 2023-08-26 16:12:29 INFO Scraped all details from Rizal Park
# 2023-08-26 16:12:31 INFO Scraped all details from Manila Cathedral
# 2023-08-26 16:12:33 INFO Scraped all details from National Museum
# 2023-08-26 16:12:35 INFO Scraped all details from Museo San Agustin
# 2023-08-26 16:12:37 INFO Scraped all details from Robinsons Place Mall
# 2023-08-26 16:12:39 INFO Scraped all details from Manila Ocean Park
# 2023-08-26 16:12:40 INFO Scraped all details from Manila Bay
# 2023-08-26 16:12:42 INFO Scraped all details from Divisoria Market
# 2023-08-26 16:12:44 INFO Scraped all details from University of Santo Tomas
# 2023-08-26 16:12:46 INFO Scraped all details from Casa Manila
# 2023-08-26 16:12:48 INFO Scraped all details from Quiapo Church
# 2023-08-26 16:12:50 INFO Scraped all details from Binondo
# 2023-08-26 16:12:52 INFO Scraped all details from Paco Park
# 2023-08-26 16:12:54 INFO Scraped all details from Binondo Church
# 2023-08-26 16:12:55 INFO Scraped all details from San Sebastian Church
# 2023-08-26 16:12:57 INFO Scraped all details from Rizal Shrine
# 2023-08-26 16:12:59 INFO Scraped all details from National Museum of Natural History
# 2023-08-26 16:13:01 INFO Scraped all details from Malate Church
# 2023-08-26 16:13:03 INFO Scraped all details from Chinatown
# 2023-08-26 16:13:05 INFO Scraped all details from Museo Filipino Intramuros
# 2023-08-26 16:13:06 INFO Scraped all details from Shangri-La Plaza
# 2023-08-26 16:13:08 INFO Scraped all details from Metropolitan Museum of Art
# 2023-08-26 16:13:10 INFO Scraped all details from 168 Shopping Mall
# 2023-08-26 16:13:12 INFO Scraped all details from Cultural Center of the Philippines
# 2023-08-26 16:13:13 INFO Scraped all details from Presidential Museum and Library
# 2023-08-26 16:13:15 INFO Scraped all details from National Museum Of Anthropology
# 2023-08-26 16:13:17 INFO Scraped all details from Memorare Manila Monument
# 2023-08-26 16:13:17 INFO Scraping the URLS of selected restaurants in Cavite
# 2023-08-26 16:13:20 INFO Scraped the URLS of 30 selected tourist destinations in Cavite
# 2023-08-26 16:13:22 INFO Scraped all details from Summit Ridge Promenade
# 2023-08-26 16:13:23 INFO Scraped all details from The Pink Sisters Chapel & Convent
# 2023-08-26 16:13:25 INFO Scraped all details from Aguinaldo Shrine
# 2023-08-26 16:13:27 INFO Scraped all details from Peoples Park In The Sky
# 2023-08-26 16:13:29 INFO Scraped all details from Museo Orlina
# 2023-08-26 16:13:31 INFO Scraped all details from Picnic Grove
# 2023-08-26 16:13:32 INFO Scraped all details from Our Lady of Manaoag at Tierra de Maria
# 2023-08-26 16:13:34 INFO Scraped all details from Mt Pico de Loro
# 2023-08-26 16:13:36 INFO Scraped all details from Puzzle Mansion Bed & Breakfast
# 2023-08-26 16:13:39 INFO Scraped all details from Ayala Malls Serin
# 2023-08-26 16:13:40 INFO Scraped all details from Malinta Tunnel
# 2023-08-26 16:13:42 INFO Scraped all details from Gratchi's Getaway Tagaytay Farm Resort
# 2023-08-26 16:13:44 INFO Scraped all details from Paradizoo
# 2023-08-26 16:13:45 INFO Scraped all details from Museo De La Salle
# 2023-08-26 16:13:47 INFO Scraped all details from Water Camp Resort
# 2023-08-26 16:13:49 INFO Scraped all details from Island Cove Resort
# 2023-08-26 16:13:51 INFO Scraped all details from Marine Base Ternate Beach
# 2023-08-26 16:13:52 INFO Scraped all details from Bonifacio Shrine
# 2023-08-26 16:13:54 INFO Scraped all details from Yoki's Farm
# 2023-08-26 16:13:56 INFO Scraped all details from Balite Falls
# 2023-08-26 16:13:58 INFO Scraped all details from Acienda Designer Outlet
# 2023-08-26 16:14:00 INFO Scraped all details from Residence Inn Zoo
# 2023-08-26 16:14:02 INFO Scraped all details from The Gingerbread House
# 2023-08-26 16:14:04 INFO Scraped all details from Mahogany Market
# 2023-08-26 16:14:05 INFO Scraped all details from Tagaytay Point
# 2023-08-26 16:14:07 INFO Scraped all details from Imus Cathedral
# 2023-08-26 16:14:08 INFO Scraped all details from Church of San Francisco de Malabon
# 2023-08-26 16:14:10 INFO Scraped all details from Nurture Farmacy
# 2023-08-26 16:14:12 INFO Scraped all details from Malibiclibic Falls
# 2023-08-26 16:14:14 INFO Scraped all details from Immaculate Conception Parish Church
# 2023-08-26 16:14:14 INFO Scraping the URLS of selected restaurants in Tagaytay
# 2023-08-26 16:14:17 INFO Scraped the URLS of 30 selected tourist destinations in Tagaytay
# 2023-08-26 16:14:19 INFO Scraped all details from Summit Ridge Promenade
# 2023-08-26 16:14:21 INFO Scraped all details from The Pink Sisters Chapel & Convent
# 2023-08-26 16:14:23 INFO Scraped all details from Museo Orlina
# 2023-08-26 16:14:25 INFO Scraped all details from Our Lady of Manaoag at Tierra de Maria
# 2023-08-26 16:14:26 INFO Scraped all details from Ayala Malls Serin
# 2023-08-26 16:14:28 INFO Scraped all details from Peoples Park In The Sky
# 2023-08-26 16:14:29 INFO Scraped all details from Puzzle Mansion Bed & Breakfast
# 2023-08-26 16:14:31 INFO Scraped all details from Picnic Grove
# 2023-08-26 16:14:33 INFO Scraped all details from Yoki's Farm
# 2023-08-26 16:14:35 INFO Scraped all details from Paradizoo
# 2023-08-26 16:14:37 INFO Scraped all details from Mahogany Market
# 2023-08-26 16:14:39 INFO Scraped all details from Our Lady of Lourdes Parish tagaytay
# 2023-08-26 16:14:40 INFO Scraped all details from Residence Inn Zoo
# 2023-08-26 16:14:42 INFO Scraped all details from Masjid Al Huda
# 2023-08-26 16:14:44 INFO Scraped all details from Tagaytay City Fruit Market
# 2023-08-26 16:14:45 INFO Scraped all details from Fora Mall Tagaytay
# 2023-08-26 16:14:47 INFO Scraped all details from Reptiland Adventure
# 2023-08-26 16:14:48 INFO Scraped all details from Nurture Wellness Village
# 2023-08-26 16:14:50 INFO Scraped all details from Sky Ranch
# 2023-08-26 16:14:52 INFO Scraped all details from Cafe Veranda Cultural Show
# 2023-08-26 16:14:53 INFO Scraped all details from Modelos Belladerm Wellness Spa and Skin Care
# 2023-08-26 16:14:55 INFO Scraped all details from The Bathhouse at Qiwellness Living
# 2023-08-26 16:14:57 INFO Scraped all details from Nail Impressions
# 2023-08-26 16:14:58 INFO Scraped all details from Luxury Day Massage & Spa Tagaytay
# Traceback (most recent call last):
#   File "d:\Educational Others\SPARTA Files\SP702 - Python for Data Engineering\SP702Capstone\tripadvisor\tourist_site.py", line 111, in extractData
#     attraction_info, attraction_review = self.getItemInfo( BeautifulSoup(self.driver.page_source, "html.parser") , attraction_url, location)
#   File "d:\Educational Others\SPARTA Files\SP702 - Python for Data Engineering\SP702Capstone\tripadvisor\tourist_site.py", line 79, in getItemInfo
#     for review_elements in page.find("div","LbPSX").contents[0].contents:
# AttributeError: 'NoneType' object has no attribute 'contents'
# 2023-08-26 16:15:00 WARNING An error has occured on /Attraction_Review-g317121-d13848005-Reviews-Calis_Wellness_Massage-Tagaytay_Cavite_Province_Calabarzon_Region_Luzon.html:None
# Traceback (most recent call last):
#   File "d:\Educational Others\SPARTA Files\SP702 - Python for Data Engineering\SP702Capstone\tripadvisor\tourist_site.py", line 111, in extractData
#     attraction_info, attraction_review = self.getItemInfo( BeautifulSoup(self.driver.page_source, "html.parser") , attraction_url, location)
#   File "d:\Educational Others\SPARTA Files\SP702 - Python for Data Engineering\SP702Capstone\tripadvisor\tourist_site.py", line 79, in getItemInfo
#     for review_elements in page.find("div","LbPSX").contents[0].contents:
# AttributeError: 'NoneType' object has no attribute 'contents'
# 2023-08-26 16:15:01 WARNING An error has occured on /Attraction_Review-g317121-d19572891-Reviews-K_and_K_TRANSPORT_SERVICE-Tagaytay_Cavite_Province_Calabarzon_Region_Luzon.html:None
# Traceback (most recent call last):
#   File "d:\Educational Others\SPARTA Files\SP702 - Python for Data Engineering\SP702Capstone\tripadvisor\tourist_site.py", line 111, in extractData
#     attraction_info, attraction_review = self.getItemInfo( BeautifulSoup(self.driver.page_source, "html.parser") , attraction_url, location)
#   File "d:\Educational Others\SPARTA Files\SP702 - Python for Data Engineering\SP702Capstone\tripadvisor\tourist_site.py", line 79, in getItemInfo
#     for review_elements in page.find("div","LbPSX").contents[0].contents:
# AttributeError: 'NoneType' object has no attribute 'contents'
# 2023-08-26 16:15:03 WARNING An error has occured on /Attraction_Review-g317121-d18817757-Reviews-Purple_Orchid_Spa-Tagaytay_Cavite_Province_Calabarzon_Region_Luzon.html:None
# Traceback (most recent call last):
#   File "d:\Educational Others\SPARTA Files\SP702 - Python for Data Engineering\SP702Capstone\tripadvisor\tourist_site.py", line 111, in extractData
#     attraction_info, attraction_review = self.getItemInfo( BeautifulSoup(self.driver.page_source, "html.parser") , attraction_url, location)
#   File "d:\Educational Others\SPARTA Files\SP702 - Python for Data Engineering\SP702Capstone\tripadvisor\tourist_site.py", line 79, in getItemInfo
#     for review_elements in page.find("div","LbPSX").contents[0].contents:
# AttributeError: 'NoneType' object has no attribute 'contents'
# 2023-08-26 16:15:04 WARNING An error has occured on /Attraction_Review-g317121-d23746501-Reviews-Niyama_Wellness_Center-Tagaytay_Cavite_Province_Calabarzon_Region_Luzon.html:None
# 2023-08-26 16:15:06 INFO Scraped all details from Nuat Thai
# 2023-08-26 16:15:08 INFO Scraped all details from Esquieres Travel Day Tours
# 2023-08-26 16:15:08 INFO Scraped all 86 tourist destinations in Tagaytay
# Tourist Site Details
#                  name location  \
# 0          Intramuros   Manila
# 1       Fort Santiago   Manila
# 2  San Agustin Church   Manila
# 3          Rizal Park   Manila
# 4    Manila Cathedral   Manila
#
#                                                  url  \
# 0  https://www.tripadvisor.com.ph/Attraction_Revi...
# 1  https://www.tripadvisor.com.ph/Attraction_Revi...
# 2  https://www.tripadvisor.com.ph/Attraction_Revi...
# 3  https://www.tripadvisor.com.ph/Attraction_Revi...
# 4  https://www.tripadvisor.com.ph/Attraction_Revi...
#
#                                                about    operating_hours  \
# 0  Intramuros, "The Walled City," is the oldest d...  8:00 AM - 6:00 PM
# 1  This museum and public park was built as a sto...                NaN
# 2  This museum and courtyard gardens is one of th...                NaN
# 3                                                NaN                NaN
# 4  Former Philippine archbishops are buried in a ...                NaN
#
#   trip_duration                             site_type  rating  review_count  \
# 0     1-2 hours  Neighborhoods,Historic Walking Areas     4.0          3594
# 1     1-2 hours                  Historic Sites,Parks     4.0          2105
# 2           NaN                       Religious Sites     4.5          1577
# 3     1-2 hours                                 Parks     4.0          2083
# 4     2-3 hours                       Religious Sites     4.0          1142
#
#   rating_description  entrance_fee  \
# 0          Very Good   6429.046667
# 1          Very Good   5604.195217
# 2          Very Good   5680.478636
# 3          Very Good   6737.211000
# 4          Very Good   3621.528000
#
#                                              address
# 0  Bonifacio Dr & Padre Burgos St, Manila, Luzon ...
# 1         Intramuros, Manila, Luzon 1002 Philippines
# 2  Gen Luna & Real Sts Intramuros, Manila, Luzon ...
# 3         Roxas Blvd, Manila, Luzon 1000 Philippines
# 4  Cabildo cor Beaterio Intramuros, Manila, Luzon...
# Tourist Site Reviews
#          name                                                url  \
# 0  Intramuros  /ShowUserReviews-g298573-d548076-r910654959-In...
# 1  Intramuros  /ShowUserReviews-g298573-d548076-r908236233-In...
# 2  Intramuros  /ShowUserReviews-g298573-d548076-r899571460-In...
# 3  Intramuros  /ShowUserReviews-g298573-d548076-r899081251-In...
# 4  Intramuros  /ShowUserReviews-g298573-d548076-r893463779-In...
#
#                                         title                    user_link  \
# 0                       Weekly Sales Training         /Profile/marikrisvis
# 1            Explore Manila’s Old Walled City         /Profile/luzlK3560IQ
# 2  Very interesting historical area of Manila      /Profile/roaming_kiwi58
# 3                         Amazing Experience   /Profile/minnieShellharbour
# 4                        Great touristy spot.          /Profile/BigBlock13
#
#             user_name rating  \
# 0        Marikrisvi S    5.0
# 1              Luz Li    5.0
# 2      roaming_kiwi58    4.0
# 3  minnieShellharbour    5.0
# 4          BigBlock13    5.0
#
#                                              content visit_date   purpose  \
# 0  Was assingend to do Sales Training with this c...   Aug 2023  Business
# 1  I do not like the traffic in Manila at all but...   Aug 2023   Couples
# 2  Intramuros is the historic old walled city par...   Mar 2023      None
# 3  What an amazing place to see. It is a must whe...   Jun 2023   Couples
# 4  Very beautiful spot in Manila, with lots of hi...   Apr 2023      None
#
#        review_date
# 0  ,15 August 2023
# 1   ,6 August 2023
# 2     ,1 July 2023
# 3    ,30 June 2023
# 4     ,4 June 2023

# %%
tourist_site_details.to_csv('final_data/Tourist_site_details.csv', index=False)
tourist_site_reviews.to_csv('final_data/Tourist_site_reviews.csv', index=False)

# %% [markdown]
# #### Full Code from tourist_site.py file:
# ```
#
# from abc import ABC, abstractmethod
# import json
# import os
# from dotenv import load_dotenv
# import requests
# import coloredlogs
# import logging.config
# import pandas as pd
# from bs4 import BeautifulSoup
# from seleniumwire import webdriver
#
# class TripadvisorWrapper(ABC):
#     # locations : dict = {}
#     driver: webdriver.Chrome
#     TRIPADVISOR_URL : str = "https://www.tripadvisor.com.ph"
#     NUM_PAGES : int = 1
#     RAPIDAPI_KEY : str = ""
#     RAPIDAPI_HOST : str = ""
#
#     def __init__(self, locations_file = "datasets/locations.json", NUM_PAGES = 1):
#         # self.locations = json.load(open(locations_file, "r"))
#         load_dotenv('credentials.env')
#         self.RAPIDAPI_KEY = os.getenv("RAPIDAPI-KEY")
#         self.RAPIDAPI_HOST = os.getenv("RAPIDAPI-HOST")
#         self.locations_file = locations_file
#         logging.config.dictConfig({
#             'version': 1,
#             'disable_existing_loggers': True,
#         })
#         coloredlogs.install(fmt='%(asctime)s %(levelname)s %(message)s')
#         chrome_options = webdriver.ChromeOptions()
#         prefs = {
#             "profile.managed_default_content_settings.images": 2,
#             "profile.managed_default_content_settings.javascript": 2
#         }
#         chrome_options.add_experimental_option("prefs", prefs)
#         self.driver = webdriver.Chrome(chrome_options=chrome_options)
#
#         self.NUM_PAGES = NUM_PAGES
#         self.scraped_infos = []
#         self.scraped_reviews = []
#         return
#
#     @abstractmethod
#     def extractData(self, locations):
#         pass
#
#     @abstractmethod
#     def getItemList(self, location) -> []:
#         pass
#
#     @abstractmethod
#     def getItemInfo(self, page: BeautifulSoup, url, location):
#         pass
#
#     def getDataframe(self) -> tuple[pd.DataFrame, pd.DataFrame]:
#         return  \
#             pd.DataFrame(self.scraped_infos), \
#             pd.DataFrame(self.scraped_reviews)
#
#     def getRating(self, element_classes):
#         rating_value = None
#         if "bubble_50" in element_classes:
#             rating_value = 5.0
#         elif "bubble_45" in element_classes:
#             rating_value = 4.5
#         elif "bubble_40" in element_classes:
#             rating_value = 4.0
#         elif "bubble_35" in element_classes:
#             rating_value = 3.5
#         elif "bubble_30" in element_classes:
#             rating_value = 3.0
#         elif "bubble_25" in element_classes:
#             rating_value = 2.5
#         elif "bubble_20" in element_classes:
#             rating_value = 2.0
#         elif "bubble_15" in element_classes:
#             rating_value = 1.5
#         elif "bubble_10" in element_classes:
#             rating_value = 1.0
#         return rating_value
#
#     def getRatingDescription(self,rating: float):
#         if rating > 4.5:
#             return "Excellent"
#         elif rating > 3.5:
#             return "Very Good"
#         elif rating > 2.5:
#             return "Average"
#         elif rating > 1.5:
#             return "Poor"
#         elif rating > 0.5:
#             return "Terrible"
#         else:
#             return None
#
#     def getLocationUrl(self, location, type) -> str:
#         '''
#         location : str
#         type : str -  only accepts the following: Attractions, Hotels, Restaurants, Tourism
#         '''
#         location = location.title()
#         type = type.lower()
#         locations = json.load(open("datasets/locations.json"))
#
#         if location not in locations.keys():
#             url = "https://travel-advisor.p.rapidapi.com/locations/v2/auto-complete"
#
#             querystring = {"query":location,"lang":"en_US","units":"km"}
#
#             headers = {
#                 "X-RapidAPI-Key": self.RAPIDAPI_KEY,
#                 "X-RapidAPI-Host": self.RAPIDAPI_HOST
#             }
#
#             response = requests.get(url, headers=headers, params=querystring)
#
#             suggestion = response.json()["data"]["Typeahead_autocomplete"]["results"]
#
#             locations[location] = {}
#             for i in range(4):
#                 if suggestion[i]["__typename"] == "Typeahead_QuerySuggestionItem":
#                     type = suggestion[i]["buCategory"].lower()
#
#                     locations[location][type]  = suggestion[i]["route"]["url"]
#                 elif suggestion[i]["__typename"] == "Typeahead_LocationItem":
#                     locations[location]["location"] = suggestion[i]["detailsV2"]["route"]["url"]
#
#             with open(self.locations_file, "w") as outfile:
#                 json.dump(locations, outfile)
#
#             return locations[location][type]
#
#         else:
#             return locations[location][type]
#
# from bs4 import BeautifulSoup
# import pandas as pd
# import logging
# from .wrapper import TripadvisorWrapper
# import traceback
#
# class TripadvisorTouristSite(TripadvisorWrapper):
#     def __init__(self, locations_file = "datasets/locations.json" , NUM_PAGES=1):
#             super().__init__(locations_file, NUM_PAGES)
#             return
#
#     def getItemList(self,location) -> []:
#         logging.info(f"Scraping the URLS of selected restaurants in {location}")
#         url = self.TRIPADVISOR_URL + self.getLocationUrl(location, "attractions")
#         offset = 0
#         attraction_links = []
#         for i in range(self.NUM_PAGES):
#             index = url.index('-g')
#             offset_url = url[:index] + f"-oa{offset}" + url[index:]
#             self.driver.get(offset_url)
#             attraction_list_page = BeautifulSoup(self.driver.page_source, "html.parser")
#
#             attraction_items = []
#
#             attraction_items.extend(attraction_list_page.find_all("div", class_="alPVI eNNhq PgLKC tnGGX"))
#
#             for item in attraction_items:
#                 attraction_links.append(item.contents[0].get("href"))
#
#             offset += 30
#         logging.info(f"Scraped the URLS of {len(attraction_links)} selected tourist destinations in {location}")
#         return attraction_links
#
#     def getItemInfo(self, page: BeautifulSoup, url,location):
#         attraction_info = {}
#         attraction_info["name"] = page.find("div", class_="iSVKr").contents[0].contents[0]
#         attraction_info["location"] = location
#         attraction_info["url"] = url
#         try:
#             attraction_info["about"] = page.find("div", class_="pqqta _d").contents[0].contents[0].contents[0].contents[0]
#         except:
#             pass
#         try:
#             attraction_info["operating_hours"] = page.find("span", class_="EFKKt").contents[0]
#         except:
#             pass
#         try:
#             attraction_info["trip_duration"] = page.find("div", class_="nvXSy f _Y Q2").contents[0].contents[1].contents[0].contents[0]
#         except:
#             pass
#         try:
#             attraction_info["site_type"] = page.find_all("div", class_="kUaIL")[2].contents[0].contents[0].contents[0].contents[0].replace(" • ",",")
#         except:
#             pass
#
#         try:
#             review_info = page.find_all("div", class_="jVDab o W f u w GOdjs")[1]
#             attraction_info["rating"] = float(review_info.contents[0].get("aria-label").split(" ")[0])
#             attraction_info["review_count"] = int(review_info.contents[1].contents[0].split(" ")[0].replace(",",""))
#             attraction_info["rating_description"] = self.getRatingDescription(attraction_info["rating"])
#
#         except:
#             pass
#
#         prices = []
#         for price_element in page.find_all("div", class_="biGQs _P fiohW avBIb fOtGX"):
#             try:
#                 prices.append(float(price_element.contents[0].replace("₱","").replace(",","")))
#             except:
#                 continue
#         attraction_info["entrance_fee"] = sum(prices)/len(prices) if len(prices) > 0 else None
#
#         try:
#             attraction_info["address"] = page.find("div", class_="AcNPX A").contents[0].contents[0].contents[0].contents[0].contents[0].contents[1].contents[0].contents[0]
#         except:
#             pass
#
#         attraction_reviews = []
#         for review_elements in page.find("div","LbPSX").contents[0].contents:
#             try:
#                 review = {}
#                 review["name"] = attraction_info["name"]
#                 # review["type"] = "tourist_site"
#                 review["url"] = review_elements.find_all("a",class_="BMQDV _F Gv wSSLS SwZTJ FGwzt ukgoS")[1].get("href")
#                 review["title"] = review_elements.find_all("a", class_="BMQDV _F Gv wSSLS SwZTJ FGwzt ukgoS")[1].contents[0].contents[0]
#                 review["user_link"] = review_elements.find_all("a",class_="BMQDV _F Gv wSSLS SwZTJ FGwzt ukgoS")[0].get("href")
#                 review["user_name"] = review_elements.find_all("a", class_="BMQDV _F Gv wSSLS SwZTJ FGwzt ukgoS")[0].contents[0]
#
#                 review["rating"] = review_elements.find("svg","UctUV d H0").get("aria-label").split(" ")[0]
#                 review["content"] = review_elements.find("div","biGQs _P pZUbB KxBGd").contents[0].contents[0]
#
#                 addtl_details = review_elements.find("div", class_="RpeCd").contents[0].split(" • ")
#                 review["visit_date"] = addtl_details[0]
#                 review["purpose"] = addtl_details[1] if len(addtl_details) >1 else None
#
#                 review["review_date"] = review_elements.find("div", class_="TreSq").contents[0].contents[0].replace("Written ",",")
#             except:
#                 pass
#             attraction_reviews.append(review)
#
#         logging.info(f"Scraped all details from {attraction_info['name']}")
#         return attraction_info, attraction_reviews
#
#     def extractData(self, locations):
#         for location in locations:
#             for link in self.getItemList(location):
#                 try:
#                     attraction_url = self.TRIPADVISOR_URL + link
#                     self.driver.get(attraction_url)
#
#                     attraction_info, attraction_review = self.getItemInfo( BeautifulSoup(self.driver.page_source, "html.parser") , attraction_url, location)
#
#                     self.scraped_infos.append(attraction_info)
#                     self.scraped_reviews.extend(attraction_review)
#                 except Exception as e:
#                     logging.warn(f"An error has occured on {link}:{traceback.print_exc()}")
#                     continue
#         logging.info(f"Scraped all {len(self.scraped_infos)} tourist destinations in {location}")
#         return
# ```
