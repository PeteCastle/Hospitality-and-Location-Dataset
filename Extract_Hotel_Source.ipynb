# %% [markdown]
# # SP702 Final Project (Task 1)
#
# **By**: Francis Mark M. Cayco
#
# **Github profile**: https://github.com/PeteCastle
#
# **Instructions:**
# **Prepare hotel data**
# Extract hotel data (Note: at least 25 different hotels)
# - Name of hotel
# - Location of hotel (Note: Barangay, City/Municipality, Province)
# - Amenities
# - Price range (e.g. price per person, room, or hour)
# - Number of available rooms (e.g. number of rooms for two people)
# - Other data (extract more data regarding hotels that can be used by tourists)
# - Customer reviews per attribute of hotels from review sites (e.g. customer review
# regarding the customer service of hotels). You need to gather at least 15 customer
# reviews. Make sure that each review is unique and posted by different users (i.e. no
# duplicate reviews and no duplicate username).
#
# Store the collected data in a csv file. File name format: **Hotel.csv** <br>
# Please upload your Jupyter notebook file. Filename format: **Extract_Hotel_Source.ipynb**. Note
# that you might need to create different python code per source of data. Submit all code you
# used to extract data.
#
# ## Data Sources
# 1. TripAdvisor (https://www.tripadvisor.com.ph)
# 2. RapidAPI's TripAdvisor Endpoint (https://rapidapi.com/apidojo/api/travel-advisor)
#
# ## How did I extract the data?
# 1. The GeoID of the location is obatined using the **RapidAPI's TripAdvisor Endpoint**. The GeoID is used to get the data from the TripAdvisor website.
# 2. The GeoID is referenced in the TripAdvisor website, returning the URLs of hotel, restaurants, and attractions in the location.
# 3. The list of hotels and detail of each hotel is obtained from the TripAdvisor website.
# 4. **BeautifulSoup** library to is used to extract the data hotel page.
#
# The extracted data is stored in a **CSV** file.  One for the list of hotels and another for the user reviews of each hotel.
#
#
# ## Website Screenshots
# ![](resources/images/2023-08-26-15-01-46.png)
# ![](resources/images/2023-08-26-15-02-52.png)
# ![](resources/images/2023-08-26-15-03-13.png)
#
#
# ## What are the list of the data that I have extracted?
# | **Hotel Information** |                    |
# |-----------------------|--------------------|
# | Name                  | Name of the hotel  |
# | URL                   | URL of the hotel   |
# | Address               | Full address of the hotel |
# | About                 | Description of the hotel |
# | Review_Count          | Number of reviews of the hotel |
# | Rating                | Rating of the hotel (1 to 5) |
# | Rating_Description    | Description of the rating (Excellent, Very Good, Average, Poor, Terrible) |
# | Rating_Location       | Rating of the location (1 to 5) |
# | Rating_Cleanliness    | Rating of the cleanliness (1 to 5) |
# | Rating_Service        | Rating of the service (1 to 5) |
# | Rating_Value          | Rating of the value (1 to 5) |
# | Property_Amenities    | List of amenities of the hotel |
# | Room_Features         | List of room features of the hotel |
# | Room_Types            | List of room types of the hotel |
# | Hotel_Class           | Hotel class (1 to 5 stars) |
# | Walkability_Score     | Walkability score of the hotel |
# | Walkability_Description | Description of the walkability score (Great for walkers, somewhat walkable, etc) |
# | Nearby_Restaurant_Count | Number of restaurants near the hotel |
# | Nearby_Attraction_Count | Number of attractions near the hotel |
# | Price_Range           | Price range of the hotel in PHP |
# | Old_Name              | Old name of the hotel |
# | Room_Count            | Number of rooms of the hotel |
#
#
# | **Hotel Review** |                    |
# |-----------------------|--------------------|
# | Name                  | Name of the hotel  |
# | Rating                | Reviewer's rating |
# | Rating_Date           | Date of the review |
# | Title                 | Title of the review |
# | Content               | Content of the review |
# | Visit_Date            | Date when the customer visited the hotel |
# | URL                   | URL of the review |

# %%
# The full code is in the file `tripadvisor/hotel.py``
from tripadvisor.hotel import TripadvisorHotel

NUM_PAGES = 1 # Number of pages to scrape.  The total number of hotels scraped is NUM_PAGES * 30

# List of locations to scrape.  
#  Note that if the location is present in datasets/locations.json, the location will be scraped. 
#  Otherwise, the location will have to be obtained from RapidAPI's Tripadvisor API, which require credential access.
#  The locations available are: Manila, Baguio, Cavite, and Tagaytay
locations = ["Manila", "Cavite","Tagaytay"] 

hotels = TripadvisorHotel(NUM_PAGES)
hotels.extractData(locations)
hotel_details, hotel_reviews = hotels.getDataframe()

print("Hotel Details")
display(hotel_details.head(5))

print("Hotel Reviews")
display(hotel_reviews.head(5))
# Out:
# 2023-08-26 15:08:28 INFO Scraping the URLS of selected restaurants in Manila
# 2023-08-26 15:08:32 INFO Scraped the URLS of 30 selected restaurants in Manila
# 2023-08-26 15:08:39 INFO Scraped all details from New Coast Hotel Manila
# 2023-08-26 15:08:41 INFO Scraped all details from Sofitel Philippine Plaza Manila
# 2023-08-26 15:08:44 INFO Scraped all details from Diamond Hotel Philippines
# 2023-08-26 15:08:46 INFO Scraped all details from The Manila Hotel
# 2023-08-26 15:08:49 INFO Scraped all details from Hotel H2O
# 2023-08-26 15:08:51 INFO Scraped all details from The Bayleaf Intramuros
# 2023-08-26 15:08:53 INFO Scraped all details from Hotel Lucky Chinatown
# 2023-08-26 15:08:55 INFO Scraped all details from City Garden Suites
# 2023-08-26 15:08:57 INFO Scraped all details from Bayview Park Hotel Manila
# 2023-08-26 15:08:59 INFO Scraped all details from Red Planet Manila Binondo
# 2023-08-26 15:09:01 INFO Scraped all details from 1775 Adriatico Suites
# 2023-08-26 15:09:03 INFO Scraped all details from Rizal Park Hotel
# 2023-08-26 15:09:07 INFO Scraped all details from Red Planet Manila Bay
# 2023-08-26 15:09:09 INFO Scraped all details from Century Park Hotel
# 2023-08-26 15:09:11 INFO Scraped all details from Hotel Kimberly Manila
# 2023-08-26 15:09:14 INFO Scraped all details from Regency Grand Suites
# 2023-08-26 15:09:18 INFO Scraped all details from Manila Prince Hotel
# 2023-08-26 15:09:20 INFO Scraped all details from Tropicana Suites
# 2023-08-26 15:09:22 INFO Scraped all details from Hop Inn Hotel Ermita Manila
# 2023-08-26 15:09:25 INFO Scraped all details from Winford Manila Resort & Casino
# 2023-08-26 15:09:27 INFO Scraped all details from Swiss-Belhotel Blulane
# 2023-08-26 15:09:29 INFO Scraped all details from Manila Lotus Hotel
# 2023-08-26 15:09:31 INFO Scraped all details from Eurotel Pedro Gil
# 2023-08-26 15:09:34 INFO Scraped all details from Red Planet Manila Mabini
# 2023-08-26 15:09:36 INFO Scraped all details from Armada Hotel Manila
# 2023-08-26 15:09:38 INFO Scraped all details from Go Hotels Otis-Manila
# 2023-08-26 15:09:40 INFO Scraped all details from Go Hotels Ermita
# 2023-08-26 15:09:42 INFO Scraped all details from Time Travellers Hotel
# 2023-08-26 15:09:44 INFO Scraped all details from Paragon Tower Hotel
# 2023-08-26 15:09:46 INFO Scraped all details from Sunny Bay Suites
# 2023-08-26 15:09:46 INFO Scraping the URLS of selected restaurants in Cavite
# 2023-08-26 15:09:48 INFO Scraped the URLS of 30 selected restaurants in Cavite
# 2023-08-26 15:09:55 INFO Scraped all details from Quest Hotel Tagaytay
# 2023-08-26 15:10:02 INFO Scraped all details from Taal Vista Hotel
# 2023-08-26 15:10:09 INFO Scraped all details from Hotel Kimberly Tagaytay
# 2023-08-26 15:10:16 INFO Scraped all details from The Bayleaf Cavite
# 2023-08-26 15:10:22 INFO Scraped all details from Escala Tagaytay
# 2023-08-26 15:10:29 INFO Scraped all details from Anya Resort Tagaytay
# 2023-08-26 15:10:36 INFO Scraped all details from Via Appia Tagaytay
# 2023-08-26 15:10:44 INFO Scraped all details from The Lake Hotel Tagaytay
# 2023-08-26 15:10:51 INFO Scraped all details from Summit Ridge Tagaytay
# 2023-08-26 15:10:58 INFO Scraped all details from View Park Hotel
# 2023-08-26 15:11:05 INFO Scraped all details from Hotel Casiana Tagaytay
# 2023-08-26 15:11:12 INFO Scraped all details from One Tagaytay Place Hotel Suites
# 2023-08-26 15:11:20 INFO Scraped all details from Microtel by Wyndham South Forbes Near Nuvali
# 2023-08-26 15:11:27 INFO Scraped all details from Nurture Wellness Village
# 2023-08-26 15:11:34 INFO Scraped all details from Royale Parc Hotel Tagaytay
# 2023-08-26 15:11:42 INFO Scraped all details from Lee Boutique Hotel
# 2023-08-26 15:11:50 INFO Scraped all details from Hotel Monticello
# 2023-08-26 15:11:58 INFO Scraped all details from The Carmelence View
# 2023-08-26 15:12:06 INFO Scraped all details from Tagaytay Country Hotel
# 2023-08-26 15:12:15 INFO Scraped all details from Estancia Resort
# 2023-08-26 15:12:23 INFO Scraped all details from The Carmelence Lodge
# 2023-08-26 15:12:32 INFO Scraped all details from La Bella Boutique Hotel
# 2023-08-26 15:12:39 INFO Scraped all details from Spring Plaza Hotel
# 2023-08-26 15:12:47 INFO Scraped all details from Tagaytay Staycation By Naya & Darla
# 2023-08-26 15:12:55 INFO Scraped all details from Alfonso Hotel
# 2023-08-26 15:13:03 INFO Scraped all details from Tagaytay Hotel Sixb
# 2023-08-26 15:13:10 INFO Scraped all details from La Gracia Apartelle
# 2023-08-26 15:13:18 INFO Scraped all details from Chona and Christophe Guesthouse
# 2023-08-26 15:13:26 INFO Scraped all details from RedDoorz @ Km 50 Aguinaldo Highway Tagaytay
# 2023-08-26 15:13:28 INFO Scraped all details from EL Renzo Hotel Tagaytay
# 2023-08-26 15:13:28 INFO Scraping the URLS of selected restaurants in Tagaytay
# 2023-08-26 15:13:31 INFO Scraped the URLS of 30 selected restaurants in Tagaytay
# 2023-08-26 15:13:39 INFO Scraped all details from Quest Hotel Tagaytay
# 2023-08-26 15:13:47 INFO Scraped all details from Taal Vista Hotel
# 2023-08-26 15:13:57 INFO Scraped all details from Hotel Kimberly Tagaytay
# 2023-08-26 15:14:06 INFO Scraped all details from Escala Tagaytay
# 2023-08-26 15:14:16 INFO Scraped all details from Anya Resort Tagaytay
# 2023-08-26 15:14:25 INFO Scraped all details from Via Appia Tagaytay
# 2023-08-26 15:14:36 INFO Scraped all details from The Lake Hotel Tagaytay
# 2023-08-26 15:14:45 INFO Scraped all details from Summit Ridge Tagaytay
# 2023-08-26 15:14:53 INFO Scraped all details from View Park Hotel
# 2023-08-26 15:15:03 INFO Scraped all details from Hotel Casiana Tagaytay
# 2023-08-26 15:15:10 INFO Scraped all details from One Tagaytay Place Hotel Suites
# 2023-08-26 15:15:19 INFO Scraped all details from Nurture Wellness Village
# 2023-08-26 15:15:28 INFO Scraped all details from Hotel Monticello
# 2023-08-26 15:15:36 INFO Scraped all details from Royale Parc Hotel Tagaytay
# 2023-08-26 15:15:44 INFO Scraped all details from Lee Boutique Hotel
# 2023-08-26 15:15:54 INFO Scraped all details from The Carmelence View
# 2023-08-26 15:16:03 INFO Scraped all details from Estancia Resort
# 2023-08-26 15:16:13 INFO Scraped all details from The Carmelence Lodge
# 2023-08-26 15:16:22 INFO Scraped all details from Tagaytay Country Hotel
# 2023-08-26 15:16:31 INFO Scraped all details from La Bella Boutique Hotel
# 2023-08-26 15:16:39 INFO Scraped all details from Tagaytay Wingate Manor
# 2023-08-26 15:16:47 INFO Scraped all details from Crosswinds Resort Suites
# 2023-08-26 15:16:55 INFO Scraped all details from Tagaytay Staycation By Naya & Darla
# 2023-08-26 15:17:03 INFO Scraped all details from Days Hotel Tagaytay
# 2023-08-26 15:17:11 INFO Scraped all details from Tagaytay Hotel Sixb
# 2023-08-26 15:17:20 INFO Scraped all details from La Gracia Apartelle
# 2023-08-26 15:17:30 INFO Scraped all details from Alfonso Hotel
# 2023-08-26 15:17:39 INFO Scraped all details from The Nest Cafe Bed And Breakfast
# 2023-08-26 15:17:47 INFO Scraped all details from RedDoorz Plus @ The Ridge Tagaytay City
# 2023-08-26 15:17:57 INFO Scraped all details from EL Renzo Hotel Tagaytay
# 2023-08-26 15:17:57 INFO Scraped all 90 hotels in Tagaytay
# Hotel Details
#                               name  \
# 0           New Coast Hotel Manila
# 1  Sofitel Philippine Plaza Manila
# 2        Diamond Hotel Philippines
# 3                 The Manila Hotel
# 4                        Hotel H2O
#
#                                                  url  \
# 0  https://www.tripadvisor.com.ph/Hotel_Review-g2...
# 1  https://www.tripadvisor.com.ph/Hotel_Review-g2...
# 2  https://www.tripadvisor.com.ph/Hotel_Review-g2...
# 3  https://www.tripadvisor.com.ph/Hotel_Review-g2...
# 4  https://www.tripadvisor.com.ph/Hotel_Review-g2...
#
#                                              address  \
# 0  1588 Pedro Gil Street Corner MH del Pilar, Man...
# 1  Roxas Boulevard CCP Complex, Manila, Luzon 130...
# 2  Roxas Boulevard cor. Dr. J. Quintos St., Manil...
# 3       1 Rizal Park, Manila, Luzon 0913 Philippines
# 4  Luneta Manila Ocean Park, Behind Quirino Grand...
#
#                                                about  review_count  rating  \
# 0  New Coast Hotel Manila is a 5-star deluxe busi...          3420     4.5
# 1  Sofitel Philippine Plaza Manila is an iconic 5...          7806     4.5
# 2  Set against the magnificent golden sunset of t...          3179     4.5
# 3  Manila Hotel embodies a rich tradition of eleg...          2013     4.0
# 4  Hotel H2O is the first and only marine-themed ...          1654     4.0
#
#   rating_description  rating_Location  rating_Cleanliness  rating_Service  \
# 0          Excellent              4.0                 4.5             4.5
# 1          Excellent              4.0                 4.5             4.5
# 2          Excellent              4.5                 4.5             4.5
# 3          Very good              4.0                 4.5             4.5
# 4          Very good              4.0                 4.0             4.0
#
#    ...                                      Room_features  \
# 0  ...  Air conditioning,Room service,VIP room facilit...
# 1  ...  Blackout curtains,Bathrobes,Air conditioning,D...
# 2  ...  Bathrobes,Air conditioning,Desk,Housekeeping,C...
# 3  ...  Air conditioning,Housekeeping,Room service,Saf...
# 4  ...  Air conditioning,Room service,Safe,Refrigerato...
#
#                                           Room_types hotel_class  \
# 0   Ocean view,Non-smoking rooms,Suites,Family rooms         5.0
# 1  Ocean view,City view,Landmark view,Bridal suit...         5.0
# 2  Ocean view,City view,Pool view,Non-smoking roo...         5.0
# 3  Ocean view,Bridal suite,Non-smoking rooms,Suit...         5.0
# 4   Ocean view,Non-smoking rooms,Suites,Family rooms         4.0
#
#   walkability_score walkability_description nearby_restaurant_count  \
# 0                97       Great for walkers                     196
# 1                57       Somewhat walkable                      30
# 2                97       Great for walkers                     186
# 3                72       Somewhat walkable                      12
# 4                68       Somewhat walkable                      12
#
#   nearby_attraction_count price_range                    old_name room_count
# 0                      16      ₱4,241  New World Manila Bay Hotel        305
# 1                       4      ₱7,634                         NaN        609
# 2                      19      ₱6,122                         NaN        483
# 3                      11      ₱4,411                         NaN        510
# 4                       8      ₱4,015                         NaN        147
#
# [5 rows x 22 columns]
# Hotel Reviews
#                      name  rating ratingDate  \
# 0  New Coast Hotel Manila     5.0     19 Aug
# 1  New Coast Hotel Manila     5.0     17 Aug
# 2  New Coast Hotel Manila     5.0      7 Aug
# 3  New Coast Hotel Manila     5.0      5 Aug
# 4  New Coast Hotel Manila     4.0   Jul 2023
#
#                                     title  \
# 0  Great place to stay. Highly recommend.
# 1               Exceeding Expectations!!!
# 2                    Good value for money
# 3      A Wonderful bad weather experience
# 4         Friendly staff and nice service
#
#                                              content   visit_date  \
# 0  Excellent place to stay. Laiza did a great job...  August 2023
# 1  This is our very first hotel stay in manila an...    July 2023
# 2  The lobby still has the same appearance as it ...    July 2023
# 3  It's been a rainy week in Metro Manila and we ...    July 2023
# 4  It was a nice hotel experience. The room atten...    July 2023
#
#                                                  url
# 0  /ShowUserReviews-g298573-d483187-r911589965-Ne...
# 1  /ShowUserReviews-g298573-d483187-r911007475-Ne...
# 2  /ShowUserReviews-g298573-d483187-r908653327-Ne...
# 3  /ShowUserReviews-g298573-d483187-r908038555-Ne...
# 4  /ShowUserReviews-g298573-d483187-r906855689-Ne...

# %%
hotel_details.to_csv('final_data/Hotel_details.csv', index=False)
hotel_reviews.to_csv('final_data/Hotel_reviews.csv', index=False)

# %% [markdown]
# #### Full Code from hotel.py file:
# ```
#
# from abc import ABC, abstractmethod
# import json
# import os
# from dotenv import load_dotenv
# import requests
# import coloredlogs
# import logging.config
# import pandas as pd
# from bs4 import BeautifulSoup
# from seleniumwire import webdriver
#
# class TripadvisorWrapper(ABC):
#     # locations : dict = {}
#     driver: webdriver.Chrome
#     TRIPADVISOR_URL : str = "https://www.tripadvisor.com.ph"
#     NUM_PAGES : int = 1
#     RAPIDAPI_KEY : str = ""
#     RAPIDAPI_HOST : str = ""
#
#     def __init__(self, locations_file = "datasets/locations.json", NUM_PAGES = 1):
#         # self.locations = json.load(open(locations_file, "r"))
#         load_dotenv('credentials.env')
#         self.RAPIDAPI_KEY = os.getenv("RAPIDAPI-KEY")
#         self.RAPIDAPI_HOST = os.getenv("RAPIDAPI-HOST")
#         self.locations_file = locations_file
#         logging.config.dictConfig({
#             'version': 1,
#             'disable_existing_loggers': True,
#         })
#         coloredlogs.install(fmt='%(asctime)s %(levelname)s %(message)s')
#         chrome_options = webdriver.ChromeOptions()
#         prefs = {
#             "profile.managed_default_content_settings.images": 2,
#             "profile.managed_default_content_settings.javascript": 2
#         }
#         chrome_options.add_experimental_option("prefs", prefs)
#         self.driver = webdriver.Chrome(chrome_options=chrome_options)
#
#         self.NUM_PAGES = NUM_PAGES
#         self.scraped_infos = []
#         self.scraped_reviews = []
#         return
#
#     @abstractmethod
#     def extractData(self, locations):
#         pass
#
#     @abstractmethod
#     def getItemList(self, location) -> []:
#         pass
#
#     @abstractmethod
#     def getItemInfo(self, page: BeautifulSoup, url, location):
#         pass
#
#     def getDataframe(self) -> tuple[pd.DataFrame, pd.DataFrame]:
#         return  \
#             pd.DataFrame(self.scraped_infos), \
#             pd.DataFrame(self.scraped_reviews)
#
#     def getRating(self, element_classes):
#         rating_value = None
#         if "bubble_50" in element_classes:
#             rating_value = 5.0
#         elif "bubble_45" in element_classes:
#             rating_value = 4.5
#         elif "bubble_40" in element_classes:
#             rating_value = 4.0
#         elif "bubble_35" in element_classes:
#             rating_value = 3.5
#         elif "bubble_30" in element_classes:
#             rating_value = 3.0
#         elif "bubble_25" in element_classes:
#             rating_value = 2.5
#         elif "bubble_20" in element_classes:
#             rating_value = 2.0
#         elif "bubble_15" in element_classes:
#             rating_value = 1.5
#         elif "bubble_10" in element_classes:
#             rating_value = 1.0
#         return rating_value
#
#     def getRatingDescription(self,rating: float):
#         if rating > 4.5:
#             return "Excellent"
#         elif rating > 3.5:
#             return "Very Good"
#         elif rating > 2.5:
#             return "Average"
#         elif rating > 1.5:
#             return "Poor"
#         elif rating > 0.5:
#             return "Terrible"
#         else:
#             return None
#
#     def getLocationUrl(self, location, type) -> str:
#         '''
#         location : str
#         type : str -  only accepts the following: Attractions, Hotels, Restaurants, Tourism
#         '''
#         location = location.title()
#         type = type.lower()
#         locations = json.load(open("datasets/locations.json"))
#
#         if location not in locations.keys():
#             url = "https://travel-advisor.p.rapidapi.com/locations/v2/auto-complete"
#
#             querystring = {"query":location,"lang":"en_US","units":"km"}
#
#             headers = {
#                 "X-RapidAPI-Key": self.RAPIDAPI_KEY,
#                 "X-RapidAPI-Host": self.RAPIDAPI_HOST
#             }
#
#             response = requests.get(url, headers=headers, params=querystring)
#
#             suggestion = response.json()["data"]["Typeahead_autocomplete"]["results"]
#
#             locations[location] = {}
#             for i in range(4):
#                 if suggestion[i]["__typename"] == "Typeahead_QuerySuggestionItem":
#                     type = suggestion[i]["buCategory"].lower()
#
#                     locations[location][type]  = suggestion[i]["route"]["url"]
#                 elif suggestion[i]["__typename"] == "Typeahead_LocationItem":
#                     locations[location]["location"] = suggestion[i]["detailsV2"]["route"]["url"]
#
#             with open(self.locations_file, "w") as outfile:
#                 json.dump(locations, outfile)
#
#             return locations[location][type]
#
#         else:
#             return locations[location][type]
#
# from bs4 import BeautifulSoup
# import pandas as pd
# import logging
# import traceback
#
# class TripadvisorHotel(TripadvisorWrapper):
#     def __init__(self, locations_file = "datasets/locations.json" , NUM_PAGES=1):
#             super().__init__(locations_file, NUM_PAGES)
#             return
#
#     def getItemList(self,location) -> []:
#         logging.info(f"Scraping the URLS of selected restaurants in {location}")
#         url = self.TRIPADVISOR_URL + self.getLocationUrl(location, "hotels")
#         offset = 0
#         hotel_links = []
#
#         for _ in range(self.NUM_PAGES):
#             index = url.index('-g')
#             offset_url = url[:index] + f"-oa{offset}" + url[index:]
#             self.driver.get(offset_url)
#             hotel_list_page = BeautifulSoup(self.driver.page_source, "html.parser")
#
#             hotel_items = []
#             hotel_items.extend(hotel_list_page.find_all("div", class_="jsTLT K"))
#
#             for item in hotel_items:
#                 hotel_links.append(item.contents[0].get("href"))
#
#             offset += 30
#         logging.info(f"Scraped the URLS of {len(hotel_items)} selected restaurants in {location}")
#         return hotel_links
#
#     def getItemInfo(self, page: BeautifulSoup, url, location):
#         hotel_info = {}
#         hotel_info["name"] = page.find("h1","QdLfr b d Pn").contents[0]
#         hotel_info["url"] = url
#         hotel_info["location"]= location
#         hotel_info["address"] = page.find("span", "fHvkI PTrfg").contents[0]
#         hotel_info["about"] = page.find("div", "fIrGe _T").contents[0]
#         hotel_info["review_count"] = int(page.find("span", "qqniT").contents[0].replace(",",""))
#         hotel_info["rating"] = float(page.find("span", "uwJeR P").contents[0])
#         hotel_info["rating_description"] = page.find("div", "kkzVG").contents[0]
#
#         #Ratings
#         ratings = page.find_all("div", "HXCfp")
#         for rating in ratings:
#             rating_type = rating.find("div", "hLoRK").contents[0]
#             classes = rating.find("span", "ui_bubble_rating")
#             rating_value = self.getRating(classes.get("class"))
#             hotel_info[f"rating_{rating_type}"] = rating_value
#
#         # More Info
#         try:
#             more_info = page.find("div", "aeQAp S5 b Pf ME").parent.contents # gets parent of the classs
#             current_info_type = ""
#             for element in more_info:
#                 if element.get("class") == None:
#                     continue
#                 if " ".join(element.get("class")) == "aeQAp S5 b Pf ME" :
#                     current_info_type = element.contents[0].replace(" ","_")
#                 elif " ".join(element.get("class")) == "OsCbb K":
#                     details = []
#                     detail_elements = element.find_all("div", "yplav f ME H3 _c")
#                     for detail_element in detail_elements:
#                         details.append(detail_element.contents[1])
#                     hotel_info[current_info_type] = ",".join(details)
#         except:
#             pass
#
#         try:
#             hotel_info["hotel_class"] = page.find("svg", "JXZuC d H0").get("aria-label").split(" ")[0]
#         except:
#             hotel_info["hotel_class"] = None
#
#         # To add:
#         # hotel style
#         # languages spoken
#
#         # Proximity Details
#         try:
#             hotel_info["walkability_score"] = page.find("span","iVKnd fSVJN").contents[0]
#             hotel_info["walkability_description"] = page.find("span","lSyvc H3 b zpbpA").contents[0]
#             hotel_info["nearby_restaurant_count"] = page.find("span","iVKnd Bznmz").contents[0]
#             hotel_info["nearby_attraction_count"] = page.find("span","iVKnd rYxbA").contents[0]
#         except:
#             pass
#
#         # Tags
#         tags_elements = page.find("div", "GFCJJ").contents[0].contents
#         current_tag = ""
#         for tag_element in tags_elements:
#             if tag_element.get("class") == None:
#                 continue
#             if " ".join(tag_element.get("class")) == "mpDVe Ci b":
#                 current_tag = tag_element.contents[0].replace(" ","_").lower()
#
#                 # modify tag elements:
#                 current_tag = "other_name" if current_tag == "also_known_as" else current_tag
#                 current_tag = "old_name" if current_tag == "formerly_known_as" else current_tag
#                 current_tag = "room_count" if current_tag == "number_of_rooms" else current_tag
#             elif " ".join(tag_element.get("class")) == "IhqAp Ci":
#                 hotel_info[current_tag] = tag_element.contents[0].replace("<!-- -->","")
#         del hotel_info["location"] #redundant
#
#         # Reviews
#         hotel_review = []
#         for review in page.find_all("div", "YibKl MC R2 Gi z Z BB pBbQr"):
#             review_info = {}
#             review_info["name"] = hotel_info["name"]
#             # review_info["type"] = "hotel"
#             review_info["rating"] = self.getRating(review.find("span", "ui_bubble_rating").get("class"))
#             review_info["ratingDate"] = review.find("div", "cRVSd").contents[0].contents[1].replace(" wrote a review ","")
#             review_info["title"] = review.find("div", "KgQgP MC _S b S6 H5 _a").contents[0].contents[0].contents[0].contents[0]
#             review_info["content"] = review.find("span", "QewHA H4 _a").contents[0].contents[0]
#             review_info["visit_date"] = review.find("span", "teHYY _R Me S4 H3").contents[1].strip()
#
#             review_info["url"] = review.find("a", "Qwuub").get("href")
#             hotel_review.append(review_info)
#         logging.info(f"Scraped all details from {hotel_info['name']}")
#         return hotel_info, hotel_review
#
#     def extractData(self, locations=[]):
#         for location in locations:
#             for link in self.getItemList(location):
#                 try:
#                     url = self.TRIPADVISOR_URL + link
#                     self.driver.get(url)
#
#                     hotel_info, hotel_review = self.getItemInfo( BeautifulSoup(self.driver.page_source, "html.parser") , url, location)
#
#                     self.scraped_infos.append(hotel_info)
#                     self.scraped_reviews.extend(hotel_review)
#                 except Exception as e:
#                     logging.warn(f"An error has occured on {link}:{traceback.print_exc()}")
#                     continue
#         logging.info(f"Scraped all {len(self.scraped_infos)} hotels in {location}")
#         return
#
# ```
